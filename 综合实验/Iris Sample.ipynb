# %%
import os
# os.environ['DEVICE_ID'] = '6'
import csv
import numpy as np

import mindspore as ms
from mindspore import nn
from mindspore import context
from mindspore import dataset
from mindspore.train.callback import LossMonitor
from mindspore.common.api import ms_function
from mindspore.ops import operations as P

context.set_context(mode=context.GRAPH_MODE, device_target="CPU")

with open('iris.data') as csv_file:
    data = list(csv.reader(csv_file, delimiter=','))
print(data[40:60]) # 打印部分数据

label_map = {
    'Iris-setosa': 0,
    'Iris-versicolor': 1,
}

X = np.array([[float(x) for x in s[:-1]] for s in data[:100]], np.float32)
Y = np.array([[label_map[s[-1]]] for s in data[:100]], np.float32)

from matplotlib import pyplot as plt
plt.scatter(X[:50, 0], X[:50, 1], label='Iris-setosa')
plt.scatter(X[50:, 0], X[50:, 1], label='Iris-versicolor')
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.legend()

train_idx = np.random.choice(100, 80, replace=False)
test_idx = np.array(list(set(range(100)) - set(train_idx)))
X_train, Y_train = X[train_idx], Y[train_idx]
X_test, Y_test = X[test_idx], Y[test_idx]

XY_train = list(zip(X_train, Y_train))
ds_train = dataset.GeneratorDataset(XY_train, ['x', 'y'])
ds_train = ds_train.shuffle(buffer_size=80).batch(32, drop_remainder=True)

coor_x = np.arange(-10, 11, dtype=np.float32)
coor_y = nn.Sigmoid()(ms.Tensor(coor_x)).asnumpy()
plt.plot(coor_x, coor_y)
plt.xlabel('x')
plt.ylabel('p')

# 自定义Loss
class Loss(nn.Cell):
    def __init__(self):
        super(Loss, self).__init__()
        self.sigmoid_cross_entropy_with_logits = P.SigmoidCrossEntropyWithLogits()
        self.reduce_mean = P.ReduceMean(keep_dims=False)
    def construct(self, x, y):
        loss = self.sigmoid_cross_entropy_with_logits(x, y)
        return self.reduce_mean(loss, -1)

net = nn.Dense(4, 1)
loss = Loss()
opt = nn.optim.SGD(net.trainable_params(), learning_rate=0.003)

model = ms.train.Model(net, loss, opt)
model.train(5, ds_train, callbacks=[LossMonitor(per_print_times=ds_train.get_dataset_size())], dataset_sink_mode=False)
# Out:
# [['5.0', '3.5', '1.3', '0.3', 'Iris-setosa'], ['4.5', '2.3', '1.3', '0.3', 'Iris-setosa'], ['4.4', '3.2', '1.3', '0.2', 'Iris-setosa'], ['5.0', '3.5', '1.6', '0.6', 'Iris-setosa'], ['5.1', '3.8', '1.9', '0.4', 'Iris-setosa'], ['4.8', '3.0', '1.4', '0.3', 'Iris-setosa'], ['5.1', '3.8', '1.6', '0.2', 'Iris-setosa'], ['4.6', '3.2', '1.4', '0.2', 'Iris-setosa'], ['5.3', '3.7', '1.5', '0.2', 'Iris-setosa'], ['5.0', '3.3', '1.4', '0.2', 'Iris-setosa'], ['7.0', '3.2', '4.7', '1.4', 'Iris-versicolor'], ['6.4', '3.2', '4.5', '1.5', 'Iris-versicolor'], ['6.9', '3.1', '4.9', '1.5', 'Iris-versicolor'], ['5.5', '2.3', '4.0', '1.3', 'Iris-versicolor'], ['6.5', '2.8', '4.6', '1.5', 'Iris-versicolor'], ['5.7', '2.8', '4.5', '1.3', 'Iris-versicolor'], ['6.3', '3.3', '4.7', '1.6', 'Iris-versicolor'], ['4.9', '2.4', '3.3', '1.0', 'Iris-versicolor'], ['6.6', '2.9', '4.6', '1.3', 'Iris-versicolor'], ['5.2', '2.7', '3.9', '1.4', 'Iris-versicolor']]
# [WARNING] DEBUG(15404,python):2022-07-30-11:38:59.994.860 [mindspore/ccsrc/debug/debugger/debugger.cc:80] Debugger] Not enabling debugger. Debugger does not support CPU.
# [WARNING] KERNEL(15404,python):2022-07-30-11:39:00.222.986 [mindspore/ccsrc/backend/kernel_compiler/cpu/cpu_kernel_factory.cc:92] GetSupportedKernelAttrList] Not registered CPU kernel: op[SGD]!
# [ERROR] DEVICE(15404,python):2022-07-30-11:39:00.223.181 [mindspore/ccsrc/runtime/device/cpu/kernel_select_cpu.cc:299] SetKernelInfo] Operator[SGD] is not support. Trace:
# In file /home/ma-user/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/nn/optim/sgd.py(30)/    success = F.depend(success, opt(weight, gradient, learning_rate, accum, momentum, stat))/
# In file /home/ma-user/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/nn/optim/sgd.py(185)/            success = self.hyper_map(F.partial(_sgd_opt, self.opt, self.momentum, lr), gradients, params, accum, stat)/
# In file /home/ma-user/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/nn/wrap/cell_wrapper.py(357)/        loss = F.depend(loss, self.optimizer(grads))/
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_15404/1000742991.py in <module>
#      63
#      64 model = ms.train.Model(net, loss, opt)
# ---> 65 model.train(5, ds_train, callbacks=[LossMonitor(per_print_times=ds_train.get_dataset_size())], dataset_sink_mode=False)
#
# ~/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/train/model.py in train(self, epoch, train_dataset, callbacks, dataset_sink_mode, sink_size)
#     625                     callbacks=callbacks,
#     626                     dataset_sink_mode=dataset_sink_mode,
# --> 627                     sink_size=sink_size)
#     628
#     629     def _eval_dataset_sink_process(self, valid_dataset, list_callback=None, cb_params=None):
#
# ~/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/train/model.py in _train(self, epoch, train_dataset, callbacks, dataset_sink_mode, sink_size)
#     405             self._check_reuse_dataset(train_dataset)
#     406             if not dataset_sink_mode:
# --> 407                 self._train_process(epoch, train_dataset, list_callback, cb_params)
#     408             elif context.get_context("device_target") == "CPU":
#     409                 logger.warning("The CPU cannot support dataset sink mode currently."
#
# ~/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/train/model.py in _train_process(self, epoch, train_dataset, list_callback, cb_params)
#     534                 cb_params.train_dataset_element = next_element
#     535                 list_callback.step_begin(run_context)
# --> 536                 outputs = self._train_network(*next_element)
#     537                 cb_params.net_outputs = outputs
#     538                 if self._loss_scale_manager and self._loss_scale_manager.get_drop_overflow_update():
#
# ~/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/nn/cell.py in __call__(self, *inputs, **kwargs)
#     339             if self.enable_hook:
#     340                 raise ValueError("The graph mode does not support hook function.")
# --> 341             out = self.compile_and_run(*inputs)
#     342             return out
#     343
#
# ~/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/nn/cell.py in compile_and_run(self, *inputs)
#     606         """
#     607         self._auto_parallel_compile_and_run = True
# --> 608         self.compile(*inputs)
#     609
#     610         new_inputs = []
#
# ~/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/nn/cell.py in compile(self, *inputs)
#     593             inputs (tuple): Input parameters.
#     594         """
# --> 595         _executor.compile(self, *inputs, phase=self.phase, auto_parallel_mode=self._auto_parallel_mode)
#     596
#     597     def compile_and_run(self, *inputs):
#
# ~/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/common/api.py in compile(self, obj, phase, do_convert, auto_parallel_mode, *args)
#     492         enable_ge = context.get_context("enable_ge")
#     493         use_vm = not enable_ge or (enable_debug_runtime and context.get_context("mode") == context.PYNATIVE_MODE)
# --> 494         result = self._executor.compile(obj, args_list, phase, use_vm)
#     495         self.compile_cache[phase] = phase
#     496         if not result:
#
# RuntimeError: mindspore/ccsrc/runtime/device/cpu/kernel_select_cpu.cc:299 SetKernelInfo] Operator[SGD] is not support. Trace:
# In file /home/ma-user/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/nn/optim/sgd.py(30)/    success = F.depend(success, opt(weight, gradient, learning_rate, accum, momentum, stat))/
# In file /home/ma-user/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/nn/optim/sgd.py(185)/            success = self.hyper_map(F.partial(_sgd_opt, self.opt, self.momentum, lr), gradients, params, accum, stat)/
# In file /home/ma-user/anaconda3/envs/MindSpore/lib/python3.7/site-packages/mindspore/nn/wrap/cell_wrapper.py(357)/        loss = F.depend(loss, self.optimizer(grads))/
#
#
# #
